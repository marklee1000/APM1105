# %%
import openai
import os
import random

# Set up the OpenAI API client
openai.api_key = "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"

def generate_question(prompt):
    response = openai.Completion.create(
      engine="text-davinci-002",
      prompt=prompt,
      temperature=0.5,
      max_tokens=1024,
      top_p=1,
      frequency_penalty=0,
      presence_penalty=0
    )

    return response.choices[0].text.strip()

def create_test_prompt(topic, num_questions, num_possible_answers):
    prompt = f"Generate {num_questions} multiple-choice questions on the topic of {topic}. Each question should have {num_possible_answers} possible answers. "
    for i in range(num_questions):
        prompt += f"\n\n\nQ{i+1}. "
        question = generate_question("What is a good question about "+topic+"?") + " "
        prompt += question.capitalize()

        # Make sure the question is unique by adding a random string at the end
        prompt += f"({str(random.randint(10000, 99999))})\n"

        # Generate possible answers
        correct_answer = generate_question(f"What is the answer to the question, '{question}'?").strip()
        possible_answers = [correct_answer]

        while len(possible_answers) < num_possible_answers:
            answer = generate_question("What is a possible answer to the question, '"+question+"'?").strip()
            if answer not in possible_answers:
                possible_answers.append(answer)

        random.shuffle(possible_answers)

        # Add possible answers as multiple choice options
        for j in range(num_possible_answers):
            prompt += f"\n{chr(65+j)}. {possible_answers[j]}"

    return prompt

print(create_test_prompt("Philippine History", 4, 4))
# Out:
# Generate 4 multiple-choice questions on the topic of Philippine History. Each question should have 4 possible answers.
#
#
# Q1. What are the three major periods in philippine history? (98695)
#
# A. The three major periods in Philippine history are the Pre-Spanish period, the Spanish period, and the American period.
# B. The three major periods in Philippine history are the Spanish period, the American period, and the post-independence period.
# C. The three major periods in Philippine history are the Pre-Spanish Period, the Spanish Period, and the American Period.
# D. Pre-Spanish, Spanish, and American
#
#
# Q2. What was the role of the philippines in world war ii? (73193)
#
# A. The Philippines was a key strategic location for the United States during World War II. The country was used as a base to launch attacks against Japanese targets in the region. Additionally, the Philippines served as a valuable source of raw materials and supplies for the war effort.
# ...

# %%
import requests
import random

# URL of the raw dataset file on GitHub
url = 'https://raw.githubusercontent.com/AllenDowney/ThinkPython2/master/code/words.txt'

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Save the content of the response to a file
    with open('words.txt', 'wb') as f:
        f.write(response.content)
        print('Dataset saved to file.')
else:
    print('Failed to download dataset.')
    
with open(r'words.txt','r') as file:
    data = file.read()
    lines = data.split()

def rand_sel(x):
    #takes a random word from the list
    original_word=random.choice(lines)
    return original_word

def display(x):
    for i in range(len(original_word)):
        guessed_word.append("__")
    print(*([i for i in guessed_word]))
    
def guess(x):
    c = 8
    while(c):
        #user input
        guessed_letter = input("Guess the letter: ")
        guessed_letter = guessed_letter.lower()

        #check if guessed_letter is a letter
        if not guessed_letter.isalpha():
            c=c-1
            print(f"You can only guess a letter. {c} guesses remaining.\n")

        #check if the input is one letter only
        elif(len(guessed_letter)>1):
            c=c-1
            print(f"Guess only one letter. {c} guesses remaining.\n")

        #check if the letter entered is already guessed
        elif(guessed_letter in wrong_list):
            c=c-1
            print(f"You have already guessed this letter. {c} guesses remaining.\n")

        #check if input is correct or incorrect
        elif guessed_letter in original_word:
            for i in range(len(original_word)):
                if original_word[i] == guessed_letter:
                    guessed_word[i]=original_word[i]
            print('Correct!\n')
            wrong_list.append(guessed_letter)
        else:
            c=c-1
            print(f"Incorrect. {c} guesses remaining.\n")
            wrong_list.append(guessed_letter)

        guess_word = [i for i in guessed_word]
        guess_word = "".join(guess_word)
        if original_word == guess_word :
            print('Congratulations! You have guessed the word (ﾉ◕ヮ◕)ﾉ*:･ﾟ✧')
            c=0

        #print the guessed word
        print(*([i for i in guessed_word]))

        if c==0:
            if  original_word == guess_word  :
                exit(0)
            elif  original_word!=guessed_word  :
                print(f"Sorry, you lose. The word was {original_word} (ಥ﹏ಥ)")
                exit(0)

def main_game(x):
    global original_word, guessed_word, wrong_list

    #storage for wrong guessed and already guessed letters
    wrong_list=[]

    rand_sel(x)
    original_word=rand_sel(x)

    #create an empty list
    guessed_word = []

    display(x)
    guess(x)
    
main_game(1)
# Out:
# Dataset saved to file.
# __ __ __ __
# Guess the letter: e
# Incorrect. 7 guesses remaining.
#
# __ __ __ __
# Guess the letter: a
# Incorrect. 6 guesses remaining.
#
# __ __ __ __
# Guess the letter: i
# Correct!
#
# __ __ i __
# Guess the letter: d
# Incorrect. 5 guesses remaining.
#
# __ __ i __
# Guess the letter: s
# Incorrect. 4 guesses remaining.
#
# __ __ i __
# Guess the letter: t
# Incorrect. 3 guesses remaining.
#
# __ __ i __
# Guess the letter: r
# Correct!
#
# __ r i __
# Guess the letter: p
# Incorrect. 2 guesses remaining.
#
# __ r i __
# Guess the letter: b
# Correct!
#
# __ r i b
# Guess the letter: c
# Correct!
#
# Congratulations! You have guessed the word (ﾉ◕ヮ◕)ﾉ*:･ﾟ✧
# c r i b
